# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
laps_2024 = pd.read_csv('../data/merged/laps_2024.csv')

# %%
laps_2024.head()
# Out:
#                      Time Driver  DriverNumber                 LapTime  \
# 0  0 days 00:05:50.866000    VER             1  0 days 00:01:44.993000
# 1  0 days 00:07:28.538000    VER             1  0 days 00:01:37.672000
# 2  0 days 00:09:04.981000    VER             1  0 days 00:01:36.443000
# 3  0 days 00:10:40.086000    VER             1  0 days 00:01:35.105000
# 4  0 days 00:12:13.945000    VER             1  0 days 00:01:33.859000
#
#    LapNumber  Stint PitOutTime PitInTime             Sector1Time  \
# 0        1.0    1.0        NaN       NaN                     NaN
# 1        2.0    1.0        NaN       NaN  0 days 00:00:28.815000
# 2        3.0    1.0        NaN       NaN  0 days 00:00:28.620000
# 3        4.0    1.0        NaN       NaN  0 days 00:00:28.103000
# 4        5.0    1.0        NaN       NaN  0 days 00:00:27.574000
#
#               Sector2Time  ...             LapStartDate TrackStatus Position  \
# ...

# %%
valid_laps = laps_2024[laps_2024['LapTime'].notnull()]

# %%
valid_laps.shape
# Out:
# (27537, 34)

# %%
laps_2024.shape
# Out:
# (27783, 34)

# %%
valid_laps['LapTime'] = pd.to_timedelta(valid_laps['LapTime']).dt.total_seconds()
# Out:
# /var/folders/7p/jh7c68jx4wzbzkr7l6gf6rv80000gn/T/ipykernel_80011/1137689073.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid_laps['LapTime'] = pd.to_timedelta(valid_laps['LapTime']).dt.total_seconds()

# %%
valid_laps['LapTime']
# Out:
# 0        104.993
# 1         97.672
# 2         96.443
# 3         95.105
# 4         93.859
#           ...
# 27778     98.180
# 27779     99.104
# 27780     97.954
# 27781     97.924
# 27782     99.112
# Name: LapTime, Length: 27537, dtype: float64

# %%
fastest_laps = valid_laps.groupby('Driver')['LapTime'].min().sort_values()

# %%
valid_laps[['Driver', 'LapTime', 'RaceName']].sort_values('LapTime').head(20)
# Out:
#       Driver  LapTime             RaceName
# 12519    ALO   67.694  Austrian Grand Prix
# 11599    VER   67.719  Austrian Grand Prix
# 12641    NOR   68.016  Austrian Grand Prix
# 11601    VER   68.072  Austrian Grand Prix
# 11600    VER   68.321  Austrian Grand Prix
# 12642    NOR   68.429  Austrian Grand Prix
# 11602    VER   68.518  Austrian Grand Prix
# 11587    VER   68.623  Austrian Grand Prix
# 11374    PIA   68.697  Austrian Grand Prix
# 12645    NOR   68.751  Austrian Grand Prix
# 12644    NOR   68.770  Austrian Grand Prix
# 11584    VER   68.772  Austrian Grand Prix
# 11585    VER   68.789  Austrian Grand Prix
# 11373    PIA   68.837  Austrian Grand Prix
# 11588    VER   68.975  Austrian Grand Prix
# 11372    PIA   69.014  Austrian Grand Prix
# 11375    PIA   69.048  Austrian Grand Prix
# 11371    PIA   69.088  Austrian Grand Prix
# 11387    PIA   69.159  Austrian Grand Prix
# 12646    NOR   69.161  Austrian Grand Prix

# %%
import seaborn as sns

# %%
fastest_laps_sorted = valid_laps.sort_values('LapTime')

# %%
plt.figure(figsize=(12,8))
sns.barplot(data=fastest_laps_sorted,
            x='LapTime',
            y='Driver',
            palette='viridis')
for index, row in fastest_laps_sorted.iterrows():
    plt.text(
        row['LapTime'] + 0.2, 
        index,                       
        f"{row['LapTime']}",          
        va='center'
    )
plt.xlabel('Fastest Lap Time ')
plt.ylabel('Driver')
plt.title('Fastest Lap Per Driver')
plt.tight_layout()
plt.show()
